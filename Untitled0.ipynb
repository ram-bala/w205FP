# %%
sc

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-4e97e835d7cf> in <module>()
# ----> 1 from IPython.external import mathjax; mathjax.install_mathjax()
#
# /usr/lib/python2.6/site-packages/IPython/external/mathjax.pyc in install_mathjax(tag, dest, replace, file, extractor)
#     171         mathjax_url = "https://github.com/mathjax/MathJax/tarball/%s" % tag
#     172         print "Downloading mathjax source from %s" % mathjax_url
# --> 173         response = urllib2.urlopen(mathjax_url)
#     174         file = response.fp
#     175
#
# /usr/lib64/python2.6/urllib2.pyc in urlopen(url, data, timeout)
#     124     if _opener is None:
#     125         _opener = build_opener()
# --> 126     return _opener.open(url, data, timeout)
#     127
#     128 def install_opener(opener):
#
# /usr/lib64/python2.6/urllib2.pyc in open(self, fullurl, data, timeout)
# ...
